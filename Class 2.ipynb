# %%
s = "ineuron"

# %%
type (s)
# Out:
# str

# %%
s[0]
# Out:
# 'i'

# %%
s[5]
# Out:
# 'o'

# %%
s[-1]
# Out:
# 'n'

# %%
s1= 'sudh'

# %%
type (s1)
# Out:
# str

# %%
s1[-1]
# Out:
# 'h'

# %%
s1[-2]
# Out:
# 'd'

# %%
s2="this is my very first programming class's"

# %%
s2
# Out:
# "this is my very first programming class's"

# %%
s2[8]
# Out:
# 'm'

# %%
s2[1:5]
# Out:
# 'his '

# %%
s2[6:30]
# Out:
# 's my very first programm'

# %%
s2[6:30:2]
# Out:
# 'sm eyfrtporm'

# %%
s='sudhanshu'

# %%
s[0:9:2]
# Out:
# 'sdasu'

# %%
s
# Out:
# 'sudhanshu'

# %%
s[0:8:-1]
# Out:
# ''

# %%
s[8:0:-1]
# Out:
# 'uhsnahdu'

# %%
s[8:0:-2]
# Out:
# 'usad'

# %%
s
# Out:
# 'sudhanshu'

# %%
s[:-3]
# Out:
# 'sudhan'

# %%
s[-2:]
# Out:
# 'hu'

# %%
s[::1]
# Out:
# 'sudhanshu'

# %%
s[0:50:1]
# Out:
# 'sudhanshu'

# %%
s[::-1]
# Out:
# 'uhsnahdus'

# %%
s2
# Out:
# "this is my very first programming class's"

# %%
s2
# Out:
# "this is my very first programming class's"

# %%
s2[::-1]
# Out:
# "s'ssalc gnimmargorp tsrif yrev ym si siht"

# %%
s3='ineuron'

# %%
s3
# Out:
# 'ineuron'

# %%
s3[::-1]
# Out:
# 'norueni'

# %%
s3[-2:-7:1]
# Out:
# ''

# %%
s3[-7:-2:1]
# Out:
# 'ineur'

# %%
s
# Out:
# 'sudhanshu'

# %%
s+1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13096/3519921828.py in <module>
# ----> 1 s+1
#
# TypeError: can only concatenate str (not "int") to str

# %%
s+'1'
# Out:
# 'sudhanshu1'

# %%
s+str(1)
# Out:
# 'sudhanshu1'

# %%
'sudh'+'12343243434'
# Out:
# 'sudh12343243434'

# %%
s
# Out:
# 'sudhanshu'

# %%
len(s)
# Out:
# 9

# %%
s
# Out:
# 'sudhanshu'

# %%
s*4
# Out:
# 'sudhanshusudhanshusudhanshusudhanshu'

# %%
s
# Out:
# 'sudhanshu'

# %%
s.count('sum')
# Out:
# 0

# %%
type(s.split('u'))
# Out:
# list

# %%
s.split('u')
# Out:
# ['s', 'dhansh', '']

# %%
sw = "The Samsung Group[3] (or simply Samsung, stylized as SΛMSUNG) (Korean: 삼성 [samsʌŋ]) is a South Korean multinational manufacturing conglomerate headquartered in Samsung Town, Seoul, South Korea.[1] It comprises numerous affiliated businesses,[1] most of them united under the Samsung brand, and is the largest South Korean chaebol (business conglomerate). As of 2020, Samsung has the 8th highest global brand value.[4]

Samsung was founded by Lee Byung-chul in 1938 as a trading company. Over the next three decades, the group diversified into areas including food processing, textiles, insurance, securities, and retail. Samsung entered the electronics industry in the late 1960s and the construction and shipbuilding industries in the mid-1970s; these areas would drive its subsequent growth. Following Lee's death in 1987, Samsung was separated into five business groups – Samsung Group, Shinsegae Group, CJ Group and Hansol Group, and Joongang Group.

Notable Samsung industrial affiliates include Samsung Electronics (the world's largest information technology company, consumer electronics maker and chipmaker measured by 2017 revenues),[5][6] Samsung Heavy Industries (the world's 2nd largest shipbuilder measured by 2010 revenues),[7] and Samsung Engineering and Samsung C&T Corporation (respectively the world's 13th and 36th largest construction companies).[8] Other notable subsidiaries include Samsung Life Insurance (the world's 14th largest life insurance company),[9] Samsung Everland (operator of Everland Resort, the oldest theme park in South Korea)[10] and Cheil Worldwide (the world's 15th largest advertising agency, as measured by 2012 revenues).[11][12]"
# Out:
#   File "C:\Users\bhara\AppData\Local\Temp/ipykernel_13096/2388144102.py", line 1
#     sw = "The Samsung Group[3] (or simply Samsung, stylized as SΛMSUNG) (Korean: 삼성 [samsʌŋ]) is a South Korean multinational manufacturing conglomerate headquartered in Samsung Town, Seoul, South Korea.[1] It comprises numerous affiliated businesses,[1] most of them united under the Samsung brand, and is the largest South Korean chaebol (business conglomerate). As of 2020, Samsung has the 8th highest global brand value.[4]
#                                                                                                                                                                                                                                                                                                                                                                                                                                            ^
# SyntaxError: EOL while scanning string literal

# %%
sw="The Samsung Group[3] (or simply Samsung, stylized as SΛMSUNG) (Korean: 삼성 [samsʌŋ]) is a South Korean multinational manufacturing conglomerate headquartered in Samsung T"

# %%
sw
# Out:
# 'The Samsung Group[3] (or simply Samsung, stylized as SΛMSUNG) (Korean: 삼성 [samsʌŋ]) is a South Korean multinational manufacturing conglomerate headquartered in Samsung T'

# %%
sw.split(" ")
# Out:
# ['The',
#  'Samsung',
#  'Group[3]',
#  '(or',
#  'simply',
#  'Samsung,',
#  'stylized',
#  'as',
#  'SΛMSUNG)',
#  '(Korean:',
#  '삼성',
#  '[samsʌŋ])',
#  'is',
#  'a',
#  'South',
#  'Korean',
#  'multinational',
#  'manufacturing',
#  'conglomerate',
#  'headquartered',
#  'in',
#  'Samsung',
#  'T']

# %%
sw = """The Samsung Group[3] (or simply Samsung, stylized as SΛMSUNG) (Korean: 삼성 [samsʌŋ]) is a South Korean multinational manufacturing conglomerate headquartered in Samsung Town, Seoul, South Korea.[1] It comprises numerous affiliated businesses,[1] most of them united under the Samsung brand, and is the largest South Korean chaebol (business conglomerate). As of 2020, Samsung has the 8th highest global brand value.[4]

Samsung was founded by Lee Byung-chul in 1938 as a trading company. Over the next three decades, the group diversified into areas including food processing, textiles, insurance, securities, and retail. Samsung entered the electronics industry in the late 1960s and the construction and shipbuilding industries in the mid-1970s; these areas would drive its subsequent growth. Following Lee's death in 1987, Samsung was separated into five business groups – Samsung Group, Shinsegae Group, CJ Group and Hansol Group, and Joongang Group.

Notable Samsung industrial affiliates include Samsung Electronics (the world's largest information technology company, consumer electronics maker and chipmaker measured by 2017 revenues),[5][6] Samsung Heavy Industries (the world's 2nd largest shipbuilder measured by 2010 revenues),[7] and Samsung Engineering and Samsung C&T Corporation (respectively the world's 13th and 36th largest construction companies).[8] Other notable subsidiaries include Samsung Life Insurance (the world's 14th largest life insurance company),[9] Samsung Everland (operator of Everland Resort, the oldest theme park in South Korea)[10] and Cheil Worldwide (the world's 15th largest advertising agency, as measured by 2012 revenues).[11][12]"""

# %%
sw
# Out:
# "The Samsung Group[3] (or simply Samsung, stylized as SΛMSUNG) (Korean: 삼성 [samsʌŋ]) is a South Korean multinational manufacturing conglomerate headquartered in Samsung Town, Seoul, South Korea.[1] It comprises numerous affiliated businesses,[1] most of them united under the Samsung brand, and is the largest South Korean chaebol (business conglomerate). As of 2020, Samsung has the 8th highest global brand value.[4]\n\nSamsung was founded by Lee Byung-chul in 1938 as a trading company. Over the next three decades, the group diversified into areas including food processing, textiles, insurance, securities, and retail. Samsung entered the electronics industry in the late 1960s and the construction and shipbuilding industries in the mid-1970s; these areas would drive its subsequent growth. Following Lee's death in 1987, Samsung was separated into five business groups – Samsung Group, Shinsegae Group, CJ Group and Hansol Group, and Joongang Group.\n\nNotable Samsung industrial affiliates include Samsung Electronics (the world's largest information technology company, consumer electronics maker and chipmaker measured by 2017 revenues),[5][6] Samsung Heavy Industries (the world's 2nd largest shipbuilder measured by 2010 revenues),[7] and Samsung Engineering and Samsung C&T Corporation (respectively the world's 13th and 36th largest construction companies).[8] Other notable subsidiaries include Samsung Life Insurance (the world's 14th largest life insurance company),[9] Samsung Everland (operator of Everland Resort, the oldest theme park in South Korea)[10] and Cheil Worldwide (the world's 15th largest advertising agency, as measured by 2012 revenues).[11][12]"

# %%
sw.split(" ")
# Out:
# ['The',
#  'Samsung',
#  'Group[3]',
#  '(or',
#  'simply',
#  'Samsung,',
#  'stylized',
#  'as',
#  'SΛMSUNG)',
#  '(Korean:',
#  '삼성',
#  '[samsʌŋ])',
#  'is',
#  'a',
#  'South',
#  'Korean',
#  'multinational',
#  'manufacturing',
#  'conglomerate',
#  'headquartered',
#  'in',
#  'Samsung',
#  'Town,',
#  'Seoul,',
#  'South',
#  'Korea.[1]',
#  'It',
#  'comprises',
#  'numerous',
#  'affiliated',
#  'businesses,[1]',
#  'most',
#  'of',
#  'them',
#  'united',
#  'under',
#  'the',
#  'Samsung',
#  'brand,',
#  'and',
#  'is',
#  'the',
#  'largest',
#  'South',
#  'Korean',
#  'chaebol',
#  '(business',
#  'conglomerate).',
#  'As',
#  'of',
#  '2020,',
#  'Samsung',
#  'has',
#  'the',
#  '8th',
#  'highest',
#  'global',
#  'brand',
#  'value.[4]\n\nSamsung',
#  'was',
#  'founded',
#  'by',
#  'Lee',
#  'Byung-chul',
#  'in',
#  '1938',
#  'as',
#  'a',
#  'trading',
#  'company.',
#  'Over',
#  'the',
#  'next',
#  'three',
#  'decades,',
#  'the',
#  'group',
#  'diversified',
#  'into',
#  'areas',
#  'including',
#  'food',
#  'processing,',
#  'textiles,',
#  'insurance,',
#  'securities,',
#  'and',
#  'retail.',
#  'Samsung',
#  'entered',
#  'the',
#  'electronics',
#  'industry',
#  'in',
#  'the',
#  'late',
#  '1960s',
#  'and',
#  'the',
#  'construction',
#  'and',
#  'shipbuilding',
#  'industries',
#  'in',
#  'the',
#  'mid-1970s;',
#  'these',
#  'areas',
#  'would',
#  'drive',
#  'its',
#  'subsequent',
#  'growth.',
#  'Following',
#  "Lee's",
#  'death',
#  'in',
#  '1987,',
#  'Samsung',
#  'was',
#  'separated',
#  'into',
#  'five',
#  'business',
#  'groups',
#  '–',
#  'Samsung',
#  'Group,',
#  'Shinsegae',
#  'Group,',
#  'CJ',
#  'Group',
#  'and',
#  'Hansol',
#  'Group,',
#  'and',
#  'Joongang',
#  'Group.\n\nNotable',
#  'Samsung',
#  'industrial',
#  'affiliates',
#  'include',
#  'Samsung',
#  'Electronics',
#  '(the',
#  "world's",
#  'largest',
#  'information',
#  'technology',
#  'company,',
#  'consumer',
#  'electronics',
#  'maker',
#  'and',
#  'chipmaker',
#  'measured',
#  'by',
#  '2017',
#  'revenues),[5][6]',
#  'Samsung',
#  'Heavy',
#  'Industries',
#  '(the',
#  "world's",
#  '2nd',
#  'largest',
#  'shipbuilder',
#  'measured',
#  'by',
#  '2010',
#  'revenues),[7]',
#  'and',
#  'Samsung',
#  'Engineering',
#  'and',
#  'Samsung',
#  'C&T',
#  'Corporation',
#  '(respectively',
#  'the',
#  "world's",
#  '13th',
#  'and',
#  '36th',
#  'largest',
#  'construction',
#  'companies).[8]',
#  'Other',
#  'notable',
#  'subsidiaries',
#  'include',
#  'Samsung',
#  'Life',
#  'Insurance',
#  '(the',
#  "world's",
#  '14th',
#  'largest',
#  'life',
#  'insurance',
#  'company),[9]',
#  'Samsung',
#  'Everland',
#  '(operator',
#  'of',
#  'Everland',
#  'Resort,',
#  'the',
#  'oldest',
#  'theme',
#  'park',
#  'in',
#  'South',
#  'Korea)[10]',
#  'and',
#  'Cheil',
#  'Worldwide',
#  '(the',
#  "world's",
#  '15th',
#  'largest',
#  'advertising',
#  'agency,',
#  'as',
#  'measured',
#  'by',
#  '2012',
#  'revenues).[11][12]']

# %%
sw
# Out:
# "The Samsung Group[3] (or simply Samsung, stylized as SΛMSUNG) (Korean: 삼성 [samsʌŋ]) is a South Korean multinational manufacturing conglomerate headquartered in Samsung Town, Seoul, South Korea.[1] It comprises numerous affiliated businesses,[1] most of them united under the Samsung brand, and is the largest South Korean chaebol (business conglomerate). As of 2020, Samsung has the 8th highest global brand value.[4]\n\nSamsung was founded by Lee Byung-chul in 1938 as a trading company. Over the next three decades, the group diversified into areas including food processing, textiles, insurance, securities, and retail. Samsung entered the electronics industry in the late 1960s and the construction and shipbuilding industries in the mid-1970s; these areas would drive its subsequent growth. Following Lee's death in 1987, Samsung was separated into five business groups – Samsung Group, Shinsegae Group, CJ Group and Hansol Group, and Joongang Group.\n\nNotable Samsung industrial affiliates include Samsung Electronics (the world's largest information technology company, consumer electronics maker and chipmaker measured by 2017 revenues),[5][6] Samsung Heavy Industries (the world's 2nd largest shipbuilder measured by 2010 revenues),[7] and Samsung Engineering and Samsung C&T Corporation (respectively the world's 13th and 36th largest construction companies).[8] Other notable subsidiaries include Samsung Life Insurance (the world's 14th largest life insurance company),[9] Samsung Everland (operator of Everland Resort, the oldest theme park in South Korea)[10] and Cheil Worldwide (the world's 15th largest advertising agency, as measured by 2012 revenues).[11][12]"

# %%
sw.upper()
# Out:
ured by 2017 revenues),[5][6] samsung heavy industries (the world's 2nd largest shipbuilder measured by 2010 revenues),[7] and samsung engineering and samsung c&t corporation (respectively the world's 13th and 36th largest construction companies).[8] other notable subsidiaries include samsung life insurance (the world's 14th largest life insurance company),[9] samsung everland (operator of everland resort, the oldest theme park in south korea)[10] and cheil worldwide (the world's 15th largest advertising agency, as measured by 2012 revenues).[11][12]"

# %%
s
# Out:
# 'sudhanshu'

# %%
s.title()
# Out:
# 'Sudhanshu'

# %%
s.capitalize()
# Out:
# 'Sudhanshu'

# %%
s="Sudhanshu kuMAR"

# %%
s.capitalize()
# Out:
# 'Sudhanshu kumar'

# %%
s.swapcase()
# Out:
# 'sUDHANSHU KUmar'

# %%
''.join(reversed(s))
# Out:
# 'RAMuk uhsnahduS'

# %%
s[::-1]
# Out:
# 'RAMuk uhsnahduS'

# %%
s='        su   dh   '

# %%
s
# Out:
# '        su   dh   '

# %%
s.strip()
# Out:
# 'su   dh'

# %%
s.lstrip()
# Out:
# 'su   dh   '

# %%
s.rstrip()
# Out:
# '        su   dh'

# %%
"a" .join('sudhanshu')
# Out:
# 'sauadahaaanasahau'

# %%
s='sudh'

# %%
s.center(20, '#')
# Out:
# '########sudh########'

# %%
s='Sudhanshu'

# %%
s.isupper()
# Out:
# False

# %%
s1="SUDH"

# %%
s1.isupper()
# Out:
# True

# %%
s.islower()
# Out:
# False

# %%
s2='sudh'

# %%
s2.islower()
# Out:
# True

# %%
s
# Out:
# 'Sudhanshu'

# %%
s.isspace()
# Out:
# False

# %%
s4='    '

# %%
s4.isspace()
# Out:
# True

# %%
s
# Out:
# 'Sudhanshu'

# %%
s.isdigit()
# Out:
# False

# %%
s5='1234'

# %%
s5.isdigit()
# Out:
# True

# %%
s
# Out:
# 'Sudhanshu'

# %%
s.isalnum()
# Out:
# True

# %%
s.isalpha()
# Out:
# True

# %%
s7="12131231rasfsafs"

# %%
s7.isalpha()
# Out:
# False

# %%
s
# Out:
# 'Sudhanshu'

# %%
s.startswith('i')
# Out:
# False

# %%
s.startswith('S')
# Out:
# True

# %%
s.endswith('n')
# Out:
# False

# %%
s.endswith('u')
# Out:
# True

# %%
s
# Out:
# 'Sudhanshu'

# %%
s.isdigit()
# Out:
# False

# %%
s.isnumeric()
# Out:
# False

# %%
s.isascii()
# Out:
# True

# %%
s='sudhanshu\tkumar\tineuron'

# %%
s.expandtabs()
# Out:
# 'sudhanshu       kumar   ineuron'

# %%
s='this is My First Python programming class and i am learNING python string and its function'
1. Try to extract data from ondex one tp 300 with a jump of 3
2. Try to reverse a strong without using reverse function
3. Try to split a string after conversion of entire string in uppercase.
4. Try to convert the whole string into lower case
5. Try to capitalize the whole string.
6. write a difference betweeen isalnum() and isalpha()
7.try to give an example of expand tab
8. Give an example of strip, lstrip and rstrip
9.replace a string charecter by another charecter by taking your own example
10. try to give a defination of string centre function with an example
11. Write your own defination of compiler and interpretor without copy and paste from internet in your 
12. Python is a interpreted of compiled language give a clear ans with your understanding
13. try to write a usecase of python with your understanding
