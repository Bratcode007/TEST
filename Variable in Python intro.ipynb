# %%
sudh = 10

# %%
sudh-2
# Out:
# 8

# %%
type(sudh)
# Out:
# int

# %%
a = 34.09

# %%
type(a)
# Out:
# float

# %%
b = "this is my first class of python and today's date is 25th June 2022"

# %%
type(b)
# Out:
# str

# %%
c = "check this out"

# %%
type(c)
# Out:
# str

# %%
d = True

# %%
d
# Out:
# True

# %%
type(d)
# Out:
# bool

# %%
e = False

# %%
e
# Out:
# False

# %%
type(e)
# Out:
# bool

# %%
True - False
# Out:
# 1

# %%
False - True
# Out:
# -1

# %%
True / False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5912/2917913318.py in <module>
# ----> 1 True / False
#
# ZeroDivisionError: division by zero

# %%
False - False

# %%
n = 5+7j

# %%
type(n)

# %%
n + n

# %%
n * n

# %%
n

# %%
n.real

# %%
n.imag

# %%
n.conjugate

# %%
n.imag

# %%
b

# %%
type(b)

# %%
r = [3,4,5,6,sudh , True , 5+7j , 345.456]

# %%
type(r)
# Out:
# list

# %%
t = (23,2342,2324,"sudh")

# %%
type(t)
# Out:
# tuple

# %%
d = {'a' : "sudh" , "b" : "Bharat" , "c" : 23456}

# %%
type(d)
# Out:
# dict
